# %% [markdown]
# #Introduction to Time Series data

# %%
#@title imports
import pandas as pd
import numpy as np

# %%
#title 1.Introduction to Time Series
date_rng = pd.date_range(start='2024-01-01', periods=100, freq='D')
df = pd.DataFrame({'date': date_rng, 'value': np.random.randn(100)})
display(df.head(20))
print("Number of data points/rows: ", len(df))
# Out:
#          date     value
# 0  2024-01-01 -0.999547
# 1  2024-01-02 -0.898925
# 2  2024-01-03 -0.221074
# 3  2024-01-04  0.283960
# 4  2024-01-05 -1.258068
# 5  2024-01-06  0.374246
# 6  2024-01-07 -1.547433
# 7  2024-01-08 -0.127621
# 8  2024-01-09  1.617508
# 9  2024-01-10 -1.671548
# 10 2024-01-11  0.295769
# 11 2024-01-12  0.299992
# 12 2024-01-13  1.485662
# 13 2024-01-14  0.747338
# 14 2024-01-15 -0.362886
# 15 2024-01-16  0.719666
# 16 2024-01-17 -2.645674
# 17 2024-01-18  0.360726
# 18 2024-01-19 -0.125213
# 19 2024-01-20 -0.554154
# Number of data points/rows:  100

# %%
#@title 2. Working with Dates
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['weekday'] = df['date'].dt.weekday

display(df.head(10))
display(df.tail())
# Out:
#         date     value  year  month  day  weekday
# 0 2024-01-01 -0.999547  2024      1    1        0
# 1 2024-01-02 -0.898925  2024      1    2        1
# 2 2024-01-03 -0.221074  2024      1    3        2
# 3 2024-01-04  0.283960  2024      1    4        3
# 4 2024-01-05 -1.258068  2024      1    5        4
# 5 2024-01-06  0.374246  2024      1    6        5
# 6 2024-01-07 -1.547433  2024      1    7        6
# 7 2024-01-08 -0.127621  2024      1    8        0
# 8 2024-01-09  1.617508  2024      1    9        1
# 9 2024-01-10 -1.671548  2024      1   10        2
#          date     value  year  month  day  weekday
# 95 2024-04-05  1.251672  2024      4    5        4
# 96 2024-04-06  0.883013  2024      4    6        5
# 97 2024-04-07 -0.449769  2024      4    7        6
# 98 2024-04-08 -0.119976  2024      4    8        0
# 99 2024-04-09 -0.087728  2024      4    9        1

# %%
#@title 3. Setting Datetime Index
df.set_index('date', inplace=True)
display(df.head())
display(df.tail())
# Out:
#                value  year  month  day  weekday
# date
# 2024-01-01 -0.999547  2024      1    1        0
# 2024-01-02 -0.898925  2024      1    2        1
# 2024-01-03 -0.221074  2024      1    3        2
# 2024-01-04  0.283960  2024      1    4        3
# 2024-01-05 -1.258068  2024      1    5        4
#                value  year  month  day  weekday
# date
# 2024-04-05  1.251672  2024      4    5        4
# 2024-04-06  0.883013  2024      4    6        5
# 2024-04-07 -0.449769  2024      4    7        6
# 2024-04-08 -0.119976  2024      4    8        0
# 2024-04-09 -0.087728  2024      4    9        1

# %%
#@title 4. Slicing and Filtering Time Series Data

print("Displaying the data for a specific month")
january_data = df.loc['2024-01']  # Filter all data from January 2024
display(january_data.head(31))

print("\n\nDisplaying the data for a specific day")
specific_day_data = df.loc['2024-01-15']  # Get data for a specific day
display(specific_day_data.head())
# Out:
# Displaying the data for a specific month
#                value  year  month  day  weekday
# date
# 2024-01-01 -0.999547  2024      1    1        0
# 2024-01-02 -0.898925  2024      1    2        1
# 2024-01-03 -0.221074  2024      1    3        2
# 2024-01-04  0.283960  2024      1    4        3
# 2024-01-05 -1.258068  2024      1    5        4
# 2024-01-06  0.374246  2024      1    6        5
# 2024-01-07 -1.547433  2024      1    7        6
# 2024-01-08 -0.127621  2024      1    8        0
# 2024-01-09  1.617508  2024      1    9        1
# 2024-01-10 -1.671548  2024      1   10        2
# 2024-01-11  0.295769  2024      1   11        3
# 2024-01-12  0.299992  2024      1   12        4
# 2024-01-13  1.485662  2024      1   13        5
# 2024-01-14  0.747338  2024      1   14        6
# 2024-01-15 -0.362886  2024      1   15        0
# 2024-01-16  0.719666  2024      1   16        1
# 2024-01-17 -2.645674  2024      1   17        2
# 2024-01-18  0.360726  2024      1   18        3
# 2024-01-19 -0.125213  2024      1   19        4
# 2024-01-20 -0.554154  2024      1   20        5
# 2024-01-21 -0.818455  2024      1   21        6
# 2024-01-22 -0.532845  2024      1   22        0
# 2024-01-23 -1.315862  2024      1   23        1
# 2024-01-24  0.096157  2024      1   24        2
# 2024-01-25 -0.522087  2024      1   25        3
# 2024-01-26 -0.690919  2024      1   26        4
# 2024-01-27  0.250582  2024      1   27        5
# 2024-01-28 -0.784663  2024      1   28        6
# 2024-01-29  0.167043  2024      1   29        0
# 2024-01-30  0.989035  2024      1   30        1
# 2024-01-31  0.165307  2024      1   31        2
# Displaying the data for a specific day
# value        -0.362886
# year       2024.000000
# month         1.000000
# day          15.000000
# weekday       0.000000
# Name: 2024-01-15 00:00:00, dtype: float64

# %%
#@title 5. Resampling and Aggregation
print("Number of rows (days): ", len(df))
df_resampled = df.resample('W').mean()  # Resample weekly and take mean
print("Number of rows (weeks): ", len(df_resampled))
display(df_resampled.head())
# Out:
# Number of rows (days):  100
# Number of rows (weeks):  15
#                value    year     month        day  weekday
# date
# 2024-01-07 -0.609549  2024.0  1.000000   4.000000      3.0
# 2024-01-14  0.378157  2024.0  1.000000  11.000000      3.0
# 2024-01-21 -0.489427  2024.0  1.000000  18.000000      3.0
# 2024-01-28 -0.499948  2024.0  1.000000  25.000000      3.0
# 2024-02-04  0.000679  2024.0  1.571429  14.285714      3.0

# %%
#@title 6. Rolling Window Operations
df['rolling_mean'] = df['value'].rolling(window=7).mean()  # 7-day rolling mean
display(df.head())
display(df.head(20))
# Out:
#                value  year  month  day  weekday  rolling_mean
# date
# 2024-01-01 -0.999547  2024      1    1        0           NaN
# 2024-01-02 -0.898925  2024      1    2        1           NaN
# 2024-01-03 -0.221074  2024      1    3        2           NaN
# 2024-01-04  0.283960  2024      1    4        3           NaN
# 2024-01-05 -1.258068  2024      1    5        4           NaN
#                value  year  month  day  weekday  rolling_mean
# date
# 2024-01-01 -0.999547  2024      1    1        0           NaN
# 2024-01-02 -0.898925  2024      1    2        1           NaN
# 2024-01-03 -0.221074  2024      1    3        2           NaN
# 2024-01-04  0.283960  2024      1    4        3           NaN
# 2024-01-05 -1.258068  2024      1    5        4           NaN
# 2024-01-06  0.374246  2024      1    6        5           NaN
# 2024-01-07 -1.547433  2024      1    7        6     -0.609549
# 2024-01-08 -0.127621  2024      1    8        0     -0.484988
# 2024-01-09  1.617508  2024      1    9        1     -0.125498
# 2024-01-10 -1.671548  2024      1   10        2     -0.332708
# 2024-01-11  0.295769  2024      1   11        3     -0.331021
# 2024-01-12  0.299992  2024      1   12        4     -0.108441
# 2024-01-13  1.485662  2024      1   13        5      0.050333
# 2024-01-14  0.747338  2024      1   14        6      0.378157
# 2024-01-15 -0.362886  2024      1   15        0      0.344548
# 2024-01-16  0.719666  2024      1   16        1      0.216285
# 2024-01-17 -2.645674  2024      1   17        2      0.077124
# 2024-01-18  0.360726  2024      1   18        3      0.086403
# 2024-01-19 -0.125213  2024      1   19        4      0.025660
# 2024-01-20 -0.554154  2024      1   20        5     -0.265743

# %%
#@title 7. Shifting and Lagging
df['lagged_value'] = df['value'].shift(1)  # Lag by one time step
df['diff_value'] = df['value'].diff()  # Difference from previous step
display(df.head(10))
# Out:
#                value  year  month  day  weekday  rolling_mean  lagged_value  \
# date
# 2023-01-01 -0.995902  2023      1    1        6           NaN           NaN
# 2023-01-02  0.303281  2023      1    2        0           NaN     -0.995902
# 2023-01-03  0.359075  2023      1    3        1           NaN      0.303281
# 2023-01-04  0.844931  2023      1    4        2           NaN      0.359075
# 2023-01-05 -0.078782  2023      1    5        3           NaN      0.844931
# 2023-01-06  0.785549  2023      1    6        4           NaN     -0.078782
# 2023-01-07 -0.712449  2023      1    7        5      0.072243      0.785549
# 2023-01-08 -0.730430  2023      1    8        6      0.110168     -0.712449
# 2023-01-09 -1.503267  2023      1    9        0     -0.147910     -0.730430
# 2023-01-10  2.391826  2023      1   10        1      0.142483     -1.503267
#
#             diff_value
# date
# 2023-01-01         NaN
# 2023-01-02    1.299184
# 2023-01-03    0.055794
# 2023-01-04    0.485856
# 2023-01-05   -0.923713
# 2023-01-06    0.864331
# 2023-01-07   -1.497999
# 2023-01-08   -0.017980
# 2023-01-09   -0.772837
# 2023-01-10    3.895092
